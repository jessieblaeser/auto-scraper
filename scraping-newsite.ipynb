# %% [markdown]
# # Building a scraper for a newsite
#
# The goal is to get the headline of each article, the author, a link, and the section the article belongs in. For this proof-of-concept, we are going to be scraping [The Oklahoman](https://www.oklahoman.com/) homepage. The output will be saved in ```oklahoman.csv```
#
# Today's date: May 3, 2023

# %%
import pandas as pd
import numpy as np

import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.oklahoman.com/')
soup_doc = BeautifulSoup(response.text)

# %%
homepage = soup_doc.find(class_='gnt_cw')

# %%
divs = homepage.find_all('div')

# %%
#example
divs[0].find_all('div')[0].find('a')['href'] #how to get the href for each story
divs[0].find_all('div')[0].find('a').text #headline for story
# Out:
# ' Families grieve, demand accountability after 7 found dead in Henryetta'

# %%
#making our list to loop through using css selector
stories = homepage.select('div a')

# %% [markdown]
# ### The loop below will pull out every headline and href on the page

# %%
my_list = []

for story in stories: 
    my_dict = {}
    try:
        my_dict['headline'] = story.text
        my_dict['href'] = story['href']
    except: 
        pass
    my_list.append(my_dict)

len(my_list)
# Out:
# 41

# %%
#turn list into df
df = pd.DataFrame(my_list)
df
# Out:
#                                              headline
# 0    Families grieve, demand accountability after ...  \
# 1   Bill to help women with self defense claims re...
# 2   New $5M women's 'Sanctuary' center being built...
# 3   House passes school choice tax credit, but it ...
# 4     Live updates: Investigation into 7 found dea...
# 5    How Ethan Holliday is ‘staying in the moment’...
# 6    Oklahoma HS track & field: Bookout looks to a...
# 7    An Oklahoma native returns to Everest, raises...
# 8
# 9    Hungry for more? Head to one of these 15 Okla...
# 10   Families grieve, demand accountability after ...
# 11   Bill to help women with self defense claims r...
# 12   New $5M women's 'Sanctuary' center being buil...
# 13                                       More in News
# 14   Tramel: Why the Thunder U. team was ahead of ...
# 15   Oklahoma HS track & field: Bookout looks to a...
# 16   An Oklahoma native returns to Everest, raises...
# 17                                     More in Sports
# 18   Owners of Mayfair, no longer a 'Village,' kee...
# 19                      Making room for what matters
# 20   Commercial real estate deals from across the ...
# 21                                   More in Business
# 22   Guest column: Confessions of a dump diver And...
# 23   Stay informed on current activities in the Ok...
# 24   Guest: Lawmakers, protect job services for th...
# 25                                    More in Opinion
# 26   Happy birthday to these restaurants, plus wha...
# 27                                     Anniversaries
# 28                              High school reunions
# 29                                       More in Life
# 30
# 31                                  ENTER NOW!
# 32                                    Contests
# 33                                      Comics
# 34                                   More in Contests
# 35  Gov. Stitt signs bill banning gender-affirming...
# 36  Stitt vetoes tribal regalia at graduation, cal...
# 37  Happy birthday to these restaurants, plus what...
# 38  Tramel: Why the Thunder U. team was ahead of i...
# 39  Texas gunman who killed 5 caught after massive...
# 40
#
#                                                  href
# 0   /story/news/2023/05/02/henryetta-ok-bodies-fou...
# 1   /story/news/politics/government/2023/05/03/sel...
# 2   /story/news/2023/05/03/sanctuary-womens-develo...
# 3   /story/news/politics/government/2023/05/02/okl...
# 4   /story/news/2023/05/02/bodies-found-in-oklahom...
# 5   /story/sports/high-school/baseball/2023/05/01/...
# 6   /story/sports/high-school/track-field/2023/05/...
# 7   /story/sports/columns/jenni-carlson/2023/05/03...
# 8                                                 NaN
# 9   /story/lifestyle/food/2023/05/03/15-oklahoma-f...
# 10  /story/news/2023/05/02/henryetta-ok-bodies-fou...
# 11  /story/news/politics/government/2023/05/03/sel...
# 12  /story/news/2023/05/03/sanctuary-womens-develo...
# 13                                             /news/
# 14  /story/sports/nba/thunder/2023/05/03/okc-thund...
# 15  /story/sports/high-school/track-field/2023/05/...
# 16  /story/sports/columns/jenni-carlson/2023/05/03...
# 17                                           /sports/
# 18  /story/business/real-estate/2023/05/02/mayfair...
# 19  /story/business/real-estate/2023/04/30/marni-j...
# 20  /story/business/real-estate/2023/04/28/oklahom...
# 21                                         /business/
# 22  /story/opinion/2023/05/02/dump-diver-confessio...
# 23  /story/opinion/2023/05/01/stay-informed-on-cur...
# 24  /story/opinion/2023/05/01/sb-621-will-create-b...
# 25                                          /opinion/
# 26  /story/lifestyle/food/2023/05/03/restaurants-o...
# 27  /story/lifestyle/2023/05/03/celebrate-your-50t...
# 28  /story/lifestyle/2023/05/03/high-school-reunio...
# 29                                             /life/
# 30  /picture-gallery/news/2023/05/02/okc-catholic-...
# 31  https://usatoday.gannettcontests.com/2023-Bour...
# 32  /contests?itm_campaign=Contests&itm_medium=con...
# 33  /go-comics?itm_campaign=Comics&itm_medium=con&...
# 34  /contests/?itm_campaign=tangent.oklahoman.com&...
# 35  /story/news/politics/government/2023/05/02/okl...
# 36  /story/news/politics/government/2023/05/02/okl...
# 37  /story/lifestyle/food/2023/05/03/restaurants-o...
# 38  /story/sports/nba/thunder/2023/05/03/okc-thund...
# 39  /story/news/nation/2023/05/02/texas-shooting-g...
# 40  https://cm.oklahoman.com/site-feedback/?platfo...

# %%
#clean
df.headline = df.headline.str.strip()

# %%
#cleaning dataframe
df.drop(df[df.headline.str.contains('more in', case=False, na=False) | 
  (df.headline == 'Contests')| 
  (df.headline == 'Comics') | 
  (df.headline == 'ENTER NOW!') |
  (df.headline == 'Anniversaries') |
  (df.headline == 'High school reunions')].index, inplace=True)

# %%
df = df.reset_index(drop=True)
df
# Out:
#                                              headline
# 0   Families grieve, demand accountability after 7...  \
# 1   Bill to help women with self defense claims re...
# 2   New $5M women's 'Sanctuary' center being built...
# 3   House passes school choice tax credit, but it ...
# 4   Live updates: Investigation into 7 found dead in…
# 5   How Ethan Holliday is ‘staying in the moment’ ...
# 6   Oklahoma HS track & field: Bookout looks to ad...
